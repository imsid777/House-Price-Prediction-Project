# %% [markdown]
# ### Import the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Import the Dataset

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print (boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df = pd.DataFrame(boston.data)

# %%
df.columns = boston.feature_names

# %% [markdown]
# ### Display the Dataset

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Here, we can see that there is No Target Variable displayed.
# So, let's add the Target Variable.
#
# **NOTE:** we have renamed the **MEDV** to **PRICE** for better Understanding

# %% [markdown]
# ### Adding the Dependent Variable

# %%
df['PRICE'] = boston.target
print(df.head(10))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# ...

# %% [markdown]
# ### Display the Final Ready Dataset

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# ### Dataset Shape

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# ### Dataset description

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Here, we will look at some relationships between Independent variables and the Dependent Variable.

# %% [markdown]
# #### 1. Crime Rate & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.CRIM, df.PRICE)
plt.title('Relationship between CRIME Rate and Price of the Houses')
plt.xlabel('Per capita crime rate by town (CRIM)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Here, we can see that, as the Crime Rate increases, Price of the House decreases.

# %% [markdown]
# #### 2. Average Number of Rooms & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.RM, df.PRICE)
plt.title('Relationship between Avg. No. of Rooms and Price of the Houses')
plt.xlabel('Average number of rooms per dwelling(RM)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Positive Linear Relation:** Here, we can see that, as the No. of Rooms increases, Price of the House increases.

# %% [markdown]
# #### 3. Pupil-Teacher Ratio in Locality & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.PTRATIO, df.PRICE)
plt.title('Relationship between Pupil-Teacher Ratio and Price of the Houses')
plt.xlabel('Pupil-Teacher ratio by town(PTRATIO)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Here, we can see that, as the No. of Pupil-Teacher ratio increases, Price of the House decreases.

# %% [markdown]
# #### 4. Land Zone Proportion & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.ZN, df.PRICE)
plt.title('Relationship between Land Zone Proportion and Price of the Houses')
plt.xlabel('proportion of residential land zoned for lots over 25,000 sq.ft.(ZN)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Positive Lineaar Relation:** Here, we can see that, as the proportion of residential land zoned for lots over 25,000 sq.ft.(ZN) increases, Price of the House increases.

# %% [markdown]
# #### 5. Non-retail Business acres per town Proportion & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.INDUS, df.PRICE)
plt.title('Relationship between Non-retail Business Proportion and Price of the Houses')
plt.xlabel('proportion of non-retail business acres per town(INDUS)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Here, we can see that, as the proportion of non-retail business acres per town increases, Price of the House decreases.

# %% [markdown]
# #### 6. Nitric Oxides Concentration & PRICE

# %%
plt.figure(figsize=(10,5))
sns.regplot(df.NOX, df.PRICE)
plt.title('Relationship between Nitric Oxides Concentration and Price of the Houses')
plt.xlabel('Nitric Oxides Concentration (parts per 10 million(NOX)')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %% [markdown]
# **Negative Linear Relation:** Here, we can see that as the Nitric Oxides Concentration increases, Price of the House decreases.

# %% [markdown]
# ### Correlation Matrix

# %%
plt.figure(figsize=(16,11))
sns.heatmap(df.corr(),square=True,annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Here, we can see that **RAD** & **TAX** are Highly Corelated with PRICE.

# %%
plt.hist(df.RM)
plt.title('RM')
plt.xlabel('Avg. No. of Rooms per dwelling')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Here, we can see that Most of the Dwellings have 6 to 7 rooms.

# %% [markdown]
# # Linear Regression: Using Sklearn

# %% [markdown]
# #### Splitting the dataset into Train and Test Set.

# %%
X = df.drop('PRICE',axis=1)
y = df['PRICE']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (354, 13)
# (152, 13)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()
model.fit(X_train,y_train)
print('Score = ',model.score(X,y))
# Out:
# Score =  0.7378284679886173

# %% [markdown]
# ## Predictions:

# %%
prediction = model.predict(X_test)

# %%
plt.hist(model.predict(X_test),bins=30)
plt.title("PREDICTION PRICE")
plt.xlabel("Predicted Price")
plt.ylabel("Frequency")
plt.show()

# %%
sns.regplot(x = model.predict(X_test), y = y_test, data=prediction, fit_reg=True)
plt.xlabel("Predicted Prices")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 3.609904060381819
# MSE: 27.195965766883308
# RMSE: 5.214975145375413

# %%
sns.distplot((y_test-prediction),bins=50,color='red')

# %%
print(model.intercept_)

coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
# 37.937107741833294
#          Coefficient
# CRIM       -0.121310
# ZN          0.044466
# INDUS       0.011342
# CHAS        2.511246
# NOX       -16.231253
# RM          3.859068
# AGE        -0.009985
# DIS        -1.500270
# RAD         0.242143
# TAX        -0.011072
# PTRATIO    -1.017753
# B           0.006814
# LSTAT      -0.486738

# %% [markdown]
# **Interpretation:**
# 1. The RM Coefficient gives us the result (3.859068)
# 2. The Increase in RM increases the PRICE of houses. Which is $3.8590 increase for every 1 Unit.
